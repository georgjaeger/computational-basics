# %% [markdown]
# # Übungen zu Kapitel 3
# ## Recap Frage
# Wie groß ist `froschzahl` am Ende dieses Programms?

# %%
froschzahl = 0
frosch_dazu = 2
for it in range(2):
    froschzahl = froschzahl + frosch_dazu
    frosch_dazu = 0

print(froschzahl)

# %% [markdown]
# - 0
# - 2
# - 4
# - 6
#
# ## Aufgabe 1
# Erstelle ein For-Schleife, die die Zahlen 5 bis 10 printet. Tipp: Starte mit einer For-Schleife, die die Zahlen von 0 bis 5 printet und verwende dann deine mathematische Intuition um eine Rechenoperation zu finden, die die Zahl 0 in die Zahl 5 verwandelt.
#
# ## Aufgabe 2
# Erstelle eine If-Abfrage, die einen Alarm bei den ersten drei Werten der unten stehenden Liste auslöst, sonst aber nicht. Benutze für die If-Abfrage die Werte, nicht den Iterator.

# %%
liste = [20,23,25,10,30,50,7]
for it in range(len(liste)):
    #if-abfrage???????:
        print("Alarm bei",it)

# %% [markdown]
# ## Aufgabe 3
# Die unten stehende If-Abfrage ist sehr schwer verständlich und viele Teile sind redundant (das heißt man braucht sie eigentlich nicht). Verwende elif und else Befehle, um sie klarer zu machen.

# %%
#Eintrittspreise abhängig von Alter und Saison
preis = "?"
if alter < 12 and saison == "haupt" and saison != "neben":
    preis = "10 Euro"
if alter < 12 and saison != "haupt" and saison == "neben":
    preis = "10 Euro"
if alter >= 12 and saison == "haupt" and saison != "neben":
    preis = "15 Euro"
if alter >= 12 and alter > 8 and saison != "haupt" and saison == "neben":
    preis = "12 Euro"

print(preis)

# %% [markdown]
# ## Aufgabe 4
# Welches Problem könnte bei folgender If-Abfrage entstehen? Wie könnte man es lösen?

# %%
if temp <= 30:
    text = "Es ist nicht heiß!"
if temp >= 31:
    text = "Es ist heiß!"

print(text)

# %% [markdown]
# ## Aufgabe 5
# Korrigiere folgenden Code, der eine grüne Apel auf rot und eine rote Ampel auf grün schalten sollte, aber nicht richtig funktioiert.

# %%
farbe = "grün"

if farbe == "grün":
    farbe = "rot"
if farbe == "rot":
    farbe = "grün"

print(farbe)
# Out:
# grün

# %% [markdown]
# ## Puzzle
# Kannst du eine einzige If-Abfrage finden (also ohne and und or) die im Code unten einen Alarm bei den Zahlen 1,3,5,7 und 8 auslöst? Tipp: Du wirst zusätzlich den Iterator `it` brauchen.

# %%
liste = [1,7,3,9,5,4,7,8,2]

for it in range(len(liste)):
    #if ???????
        print("Alarm bei", liste[it])
# Out:
# Alarm bei 1
# Alarm bei 3
# Alarm bei 5
# Alarm bei 7
# Alarm bei 8

# %% [markdown]
# ## Abschluss-Frage
# Was wird hier geprintet?

# %%
preis = 10
if preis < 10:
    preis = preis + 5
if preis == 10:
    preis = preis - 4
else:
    preis = preis + 2

print(preis)

# %% [markdown]
# - 6
# - 10
# - 15
# - 17
