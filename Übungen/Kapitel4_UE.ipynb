# %% [markdown]
# # Übungen zu Kapitel 4
#
# ## Recap-Frage
# Für welchen Wert von `temp` wird hier ein Alarm geprintet?

# %%
rain = 30
if rain < temp and temp => 20:
    print("ALARM!")

# %% [markdown]
# - 20
# - 21
# - 30
# - 31

# %% [markdown]
# **Aufgabe 1**
# Ergänze eine Zeile im Code unten, um diese Liste zu erstellen: `[1,2,3,1,2,3,1,2,3]`

# %%
meineliste = [1,2,3]
# output = ????
print(output)

# %% [markdown]
# **Aufgabe 2**
# Eine 3er WG hat ihre monatlichen Kosten für Gemeingüter (Grundnahrungsmittel, Küchenutensilien,...) mitprotokolliert. Carol hat dafür eine gute App gefunden. Um die Ausgabe in Euro zu bekommen, muss man aber leider ein Premium-Abo abschließen. Deswegen ist die Währung standardmäßig São-toméische Dobra (STN). Die Währung ist über das Cotonou-Abkommen direkt an den Euro gekoppelt (1 EUR = 24,50 STN). Kannst du die Liste in Euro umrechnen?

# %%
kosten = [367.5,539,196,612.5,343,269.5]

# %% [markdown]
# **Aufgabe 3**
# Slice die folgende Liste so, dass eine Liste mit 4 Einträgen ensteht, die alle den Wert 7 haben.

# %%
sliceliste = [8,0,2,7,7,7,7,1,8,9,3]

# %% [markdown]
# **Aufgabe 4**
# Erstelle ein Dictonary, das verschiedenen Tieren die korrekte Anzahl an Beinen (als Ganzzahl) zuordnet. Teste dein Dictonary dann mit diesem Code:

# %%
tiere = ["maus","schlange","ente","laufente","ameise"]
#dic = ????
beine = 0
for it in range(len(tiere)):
    beine = beine + dic[tiere[it]]
print("Ein durchschnittliches Tier hat " + beine + " Beine.")

# %% [markdown]
# **Aufgabe 5**
# Korrigiere folgenden Code, der drei Fehler enthält.

# %%
bestellung = (
    "Nussschnecke": Carol,
    "Mohnweckerl": Bob,
    "Schokoschnecke": Alice,
    "Kornspitz": Alice,
    "Muffin": Bob,
    "Langsemmel": Carol
)

print("Die Schokoschnecke gehört "+ bestellung("Schokoschnecke")+"!")

# %% [markdown]
# **Puzzle**
# Füge in folgenden Code eine Zeile ein, sodass der Output `[[1], [2, 2], [3, 3, 3], [4, 4, 4, 4]]` geprintet wird.

# %%
liste = []
for it in range(4):
    liste.append(#???????)
print(liste)
# Out:
# [[1], [2, 2], [3, 3, 3], [4, 4, 4, 4]]

# %% [markdown]
# ## Abschluss-Frage

# %% [markdown]
# Was gibt folgender Code aus?

# %%
device_to_person = {"PC": "Alice", "Laptop": "Bob","Tablet": "Carol"}
devices= ["Tablet","PC", "Laptop"]
print(device_to_person[devices[1]])

# %% [markdown]
# - Alice
# - Bob
# - Carol
# - eine Fehlermeldung
