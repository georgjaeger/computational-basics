# %% [markdown]
# # Übungen zu Kapitel 7
# ## Recap-Frage
#
# Welche Zahl wird hier geprintet?

# %%
list1 = [1,2]
list2 = [3,4]
listoflists=[]
listoflists.append(list2)
listoflists.append(list1)
print(listoflists[0][1])

# %% [markdown]
# - 1
# - 2
# - 3
# - 4

# %% [markdown]
# ## Aufgabe 1
# Erstelle eine Function, die einen 6-seitigen, fairen Würfel simuliert. Am einfachsten geht das mit dem Befehl `random.choice`. Alternativ kann man mit `random.uniform` arbeiten und mit `int` geschickt abrunden.
#
# ## Aufgabe 2
# Erstelle eine leere Liste. Fülle sie mit 1000 Zahlen, aus der Würfel-function aus Aufgabe 1. Mache dann ein Histogramm dieser Liste.
#
# ## Aufgabe 3
# Schreibe eine neue Function, die 3 faire 6-seitige Würfel wirft und die Summe der Augenzahlen zurückgibt. Mach wieder eine Liste und fülle sie mit 1000 Outputwerten aus deiner neuen Function. Erstelle ein Histogramm dieser Liste
#
# ## Aufgabe 4
# Erstelle eine Function, die folgendes kann: Sie bekommt eine ganze Zahl `n` als Input. Dann macht sie eine Liste der Länge `n`. Jedes Element der Liste ist eine neue Zufallszahl mit Mittelwert 100 und Standardabweichung 10. Wenn die Liste erstellt ist, wandert die Function über die Liste und merkt sich immer das größte Element, das sie bisher entdeckt hat. Tipp: Ein Element ist dann das größte, wenn es größer ist als das, was bisher das größte war. ;) Das größte Element wird dann returned. Erstelle einen  Plot, der zeigt wie groß das größte Element bei n=10, n=100, n=250, n=500 und n=1000 ist.
#
# ## Aufgabe 5
# Erstelle eine Liste mit nur einem Eintrag und zwar der Zahl 1000. Mach dann eine For-Schleife über 1000 Schritte. In jedem Schritt soll eine Zufallszahl an die Liste angehängt werden. Die Zufallszahl ist gleichverteilt mit einem Minimum von 0 und einem Maximum das dem aktuell letzten Wert der Liste entspricht. Denk darüber nach, wie ein Histogramm dieser Liste aussehen könnte. Plotte dannach ein Histogramm dieser Liste.

# %% [markdown]
# ## Puzzle
# Erstelle eine Function, die einen fairen, 6-seitigen Würfel geschreibt. Du darfst aber keine Befehle aus dem random Paket (oder einem anderen Paket) verwenden, sondern nur die function `fifty_fifty`.

# %%
import random

def fifty_fifty():
    return random.choice([1,6])

def dice():
    #??????
    #...
    print(roll)

# %% [markdown]
# ## Abschluss-Frage
# Bei welcher dieser Zufallszahlen `z` kann garantiert nicht die Zahl 7 rauskommen?
#
# - `z = int(random.uniform(4,8))`
# - `z = int(random.gauss(4,1))`
# - `z = random.choice(7*[1])`
# - `z = int(random.uniform(0,random.uniform(8,10)))`
