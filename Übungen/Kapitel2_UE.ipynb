# %% [markdown]
# # Übungen zu Kapitel 2
#
# **Aufgabe 1**
# Schreibe eine for-schleife, die 5 Mal hintereinander den Text "Quack!" auf den Bildschirm schreibt.
#
#
# **Aufgabe 2**
# Wir backen 2 Tiefkühlpizzen in einem Ofen. Damit sie gleichmäßig knusprig werden, müssen wir sie nach der halben Backzeit tauschen. Die obere Pizza muss nach unten und die untere nach oben. Erweitere den Code um dieses Ziel zu erreichen, ohne das Wort "Funghi" oder "Margherita" zu schreiben.

# %%
obere_schiene = "Funghi"
mittlere_schiene = "leer"
untere_schiene = "Margherita"

# hier zeile einfügen
# hier zeile einfügen

mittlere_schiene = "leer"
print(obere_schiene)
print(untere_schiene)
# Out:
# Funghi
# Margherita

# %% [markdown]
# **Aufgabe 3**
# Wir schreiben ein Modell, das eine Hasenpopulation darstellen soll. Diese wächst immer schneller: Im ersten Zeitschritt kommen 2 Hasen dazu, dann 4, dann 8, dann 16 und so weiter. Simuliere 10 Zeitschritte und printe die resultierende Liste. Hier der Anfang des Programms:

# %%
hasen = 20
hasen_liste = [20]
hasen_dazu = 2
#forschleife einfügen:
    #hasen kommen dazu
    #hasenzahl wird an die liste angehängt
    #noch etwas passiert
print(hasen_liste)

# %% [markdown]
# **Aufgabe 4**
# Erstelle einen Plot, der die Liste aus der vorherigen Aufgabe grafisch darstellt.
#
# **Aufgabe 5**
# Erstelle eine Simulation, die eine Population von Lemmingen simuliert. Sie startet bei 1000. In jedem Zeitschritt wird die Zahl der Lemminge zuerst halbiert und dann kommen 50 Lemminge dazu. Simuliere 15 Zeitschritte und erstelle einen Plot. Was ändert sich, wenn wir stattdessen mit 10 Lemmingen (statt mit 1000) starten würden?
#
# **Puzzle**
# Füge eine Zeile zum unten stehenden Programm hinzu. Am Schluss soll folgende Liste geprintet werden: `[10, 30, 90, 270, 810]`

# %%
hasen = 10
hasen_liste = []
hasen_dazu = 0

for it in range(5):
    hasen = hasen + hasen_dazu
    #???????
    hasen_liste.append(hasen)

print(hasen_liste)
# Out:
# [10, 10, 10, 10, 10]

# %% [markdown]
# ## Abschluss-Frage
# Wie oft wird dieser Code das Wort "Hoppel!" printen?

# %%
hasen = 7
hasenbande = 10
hasenbande = hasenbande + 5
for it in range(hasenbande):
    hasen = hasen + 3
    print("Hoppel!")
print(hasen)

# %% [markdown]
# - exakt 5 mal
# - exakt 7 mal
# - exakt 10 mal
# - exakt 15 mal
