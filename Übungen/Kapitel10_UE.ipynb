# %% [markdown]
# # Übungen zu Kapitel 10
#
# ## Recap-Frage
# Welche Aussage über die Klasse `Pizza` ist **nicht** korrekt?

# %%
class Pizza():
    def __init__(self):
        self.size=random.choice["s","m","l"]
        self.zutaten = ["tomaten","käse","pilze"]
        self.temperatur = 0
    def backen(self):
        self.temperatur = 300
    def cool(self):
        self.temperatur = 60

# %% [markdown]
# - Sie hat insgesamt 3 Methoden
# - In der Initialisierungsmethode werden 3 Eigenschaften gesetzt
# - Sie hat insgesamt 5 Eigenschaften
# - Nur eine Eigenschaft ist eine Liste
#
# ## Aufgabe 1
# Schreibe die Klasse so um, dass der Konstruktor 2 Argumente braucht. Schreibe das Erstellen der Objekte so um, dass die gleichen Objekte erstellt werden wir im ursprünglichen Code.

# %%
class Car():
    def __init__(self):
        self.size=random.choice("s","m","l")
        self.age=random.uniform(0,15)
cars=[]
for it in range(100):
    cars.append(Car())

# %% [markdown]
# ## Aufgabe 2
# Bluey bellt nicht. Bitte hilf ihr.

# %%
class Hund:
    def __init__(name, alter):
        name = name
        alter = alter

    def bellen():
        print("Wuff!")

# Test
mein_hund = Hund("Bluey", 4)
mein_hund.bellen()

# %% [markdown]
# ## Aufgabe 3
#
# Schreibe eine Klasse `Spaarschwein`. Der Konstuktor braucht den Namen der Person, der das Spaarschwein gehört und setzt den Kontostand auf 0. Die Methode `einzahlen` erhöht den Kontostand um einen wählbaren Betrag. Die Methode `hammer` setzt den Kontostand wieder auf 0. Bonusaufgabe: Nachdem einmal die Methode `hammer` benutzt wurde, bleibt der Kontostand auf 0, auch wenn man versucht einzuzahlen.
#
# ## Aufgabe 4
# Verwende die unten Definierte Klasse um ein Smartphone zu erstellen (Marke und Modell kannst du dir aussuchen). Benutze es dann so lang, bis der Akku auf 25 Prozent ist und printe dann den verbleibenden Akku.

# %%
class Smartphone:
    def __init__(self, marke, modell):
        self.marke = marke
        self.modell = modell
        self.akku = 100

    def nutzen(self, prozent):
        self.akku -= prozent

# %% [markdown]
# ## Aufgabe 5
#
# Erstelle die Klassen Buch und Bibliothek, die folgendes können sollen:
#
# Klasse Buch:
#
# `__init__(self, titel, autor)`
#
# Klasse Bibliothek:
#
# `__init__(self):` Erstellt eine Eigenschaft self.buecher als leere Liste.
#
# Methode `buch_hinzufuegen(self, buch):` Fügt ein Buch-Objekt zur Liste hinzu.
#
# Methode `zeige_buecher(self):` Gibt die Titel aller Bücher aus. Wenn keine Bücher da sind, gib "Die Bibliothek ist leer." aus.
#
# Teste deine Klassen.
#
# ## Puzzle
# Alle 91 Roboter müssen eine einzigartige ganzzahlige ID zwischen 0 und 100 bekommen. Zwei Roboter, die in der Liste benachbart sind, dürfen niemals eine benachbarte ID haben (also eine ID, die nur um 1 mehr oder weniger ist). Ändere nur die Zeile `#n=???`.

# %%
class Robo():
    def __init__(self, ID):
        self.id = ID
newrobot = Robo(1)
robos=[newrobot]
for it in range(90):
    #n = ????
    newrobot = Robo(n)
    robos.append(newrobot)

# %% [markdown]
# geheime Lösung: n=(newrobot.id+2)%99)
#
# ## Abschluss-Frage
# Wo ist der Fehler in dem folgenden Code:

# %%
class PartyMonster:
    def __init__(name, lieblings_snack, tanz_level):
        self.name = name
        self.lieblings_snack = lieblings_snack
        self.tanz_level = tanz_level  # Wert von 1 bis 10

    def party_machen(self):
        print(self.name, "tanzt mit einem Tanz-Level von", self.tanz_level)
        print(self.name,"mampft gierig", self.lieblings_snack)


# Ein Monster erschaffen und Party machen
mampfi = PartyMonster("Mampfi der Schreckliche", "Käsebällchen", 11)
mampfi.party_machen()
# Out:
# Mampfi der Schreckliche tanzt mit einem Tanz-Level von 11
# Mampfi der Schreckliche mampft gierig Käsebällchen

# %% [markdown]
# - Bei der Definition der `__init__` Methode
# - Bei der Definition der `party_machen` Methode
# - Beim Erstellen des Objekts
# - Beim Aufrufen von `party_machen`
