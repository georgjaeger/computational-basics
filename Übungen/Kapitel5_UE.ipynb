# %% [markdown]
# # Übungen zu Kapitel 5
#
# ## Recap-Frage
# Was gibt folgender Code aus?

# %%
device_to_person = {"PC": "Alice", "Laptop": "Bob","Tablet": "Carol"}
devices= ["Tablet","PC", "Laptop"]
print(device_to_person[devices[2:]])

# %% [markdown]
# - Alice
# - Bob
# - Alice und Bob
# - eine Fehlermeldung

# %% [markdown]
# ## Aufgabe 1
# Erstelle eine Function, die zwei Argumente (Zahlen) annimmt und die Summe der beiden Zahlen printet.
#
# ## Aufgabe 2
# Erstelle eine Function, die ein Argument (Zahl) annimmt. Wenn die Zahl größer als 0 ist, soll sie innerhalb einer While-Schleife so lange verdoppelt werden, bis sie größer als 100 ist.
#
# ## Aufgabe 3
# Im folgenden Code sollte eine Zahl von Cent in Euro umgerechnet werden. Leider funktioniert das nicht. Finde und löse das Problem.

# %%
def umrechner(cent):
    euro = cent / 100

print(umrechner(200))
# Out:
# None

# %% [markdown]
# ## Aufgabe 4
# Schreibe eine Function, die als Input ein Dictonary annimmt und als output den ersten Wert einer Liste ausgibt, die unter dem Key "ID" gspeichert ist. Teste die Function dann mit folgendem Dictonary.

# %%
personen = {
    "name": ["Alice","Bob","Carol","Eve"],
    "ID": [879,548,413,254],
    "age": [24,28,23,26]
}

# %% [markdown]
# # Aufgabe 5
# Im folgenden Code wurde versucht mehrere Functions zu verwenden. Leider ging einiges schief. Bitte korrigiere die Definitionene der Functions, sodass der Code im Haupttteil fehlerfrei funktioniert. Die Kommentare in den Definitionen erklären, was die Functions machen sollen. Wenn alles klappt, bekommt jede Person 9 Kekse.

# %%
def mischen(zucker, mehl, butter):
    #wenn die summe aus mehl und zucker genau 2 mal die menge an butter ist, wird der eig gemacht
    if mehl + zucker == 2 * butter:
        teig = mehl + zucker
    return teig

def ausstechen(teig):
    #je 10 einheiten teig werden zu je einem keks geformt
    rohe_kekse = teig / 10
    return teig

def backen(rohe_kekse):
    #die rohen kekse werden gebacken, leider verbrennen 10%
   return fertige_kekse * 0.9

def aufteilen(kekse, personen):
    #die kekse werden gerecht verteilt
    return personen * 1 / kekse
    




# main
mehl =  300
butter = 200
zucker = 100
teig = ausstechen(mischen(mehl,butter,zucker))
kekse = backen(teig)
print("Jede Person bekommt", aufteilen(kekse,4), "Kekse.")

# %% [markdown]
# ## Puzzle
# Das Programm unten benutzt zwei Functions um den gewünschten Output `[150, 170]
# [110, 190]` zu printen. Wie kann man das auch mit nur einer Function machen (so wie in den auskommentierten Zeilen angedeutet)?

# %%
def sortieren(liste):
    a = liste[0]
    b = liste[1]
    if a < b:
        return liste
    else:
        return [liste[1],liste[0]]

def aussortieren(zahl):
    if zahl > 200 or zahl < 100:
        return "weg damit!"
    else:
        return "behalten"

listen = [[150,170],[190,110],[220,120],[140,90]]

for it in range(len(listen)):
    aktive_liste = listen[it]
    x = aktive_liste[0]
    y = aktive_liste[1]
    if aussortieren(x) != "weg damit!" and aussortieren(y) != "weg damit!":
        print(sortieren(aktive_liste))

#def allesaufeinmal(listen): 
    #????
    #...
        
#for it in range(len(listen)):
    #allesaufeinmal(listen[it])
# Out:
# [150, 170]
# [110, 190]

# %% [markdown]
# ## Abschluss-Frage
# Wie muss ich die Function `aufteilen` aufrufen, damit sie nur die Zahl 4 printet?

# %%
def aufteilen(kekse,personen):
    print(kekse/personen)
    return kekse

zimtsterne = 40
menschen = 10

# %% [markdown]
# - `print(aufteilen(zimtsterne,menschen))`
# - `print(aufteilen((kekse,personen))`
# - `aufteilen(zimtsterne,menschen)`
# - `aufteilen((kekse,personen)`
